# %% [markdown]
# **Controle estatístico de processo**
#
# Series Temporais
#
# Análise de autocorrelação

# %%
#Importando as bibliotecas

import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy import stats
import seaborn as sns
import numpy as np
from numpy.polynomial.polynomial import Polynomial

# %%
# Caminho para o arquivo Excel (substitua 'caminho_para_o_arquivo.xlsx' pelo caminho real do seu arquivo)
caminho_do_arquivo = 'time_series_01.xlsx'

# Ler o arquivo Excel
df = pd.read_excel(caminho_do_arquivo)

# Mostrar as primeiras linhas do arquivo
df.head()
# Out:
#    TS1   TS2   TS3
# 0   86  44.0  54.0
# 1   85  44.0  53.0
# 2   85  43.0  52.0
# 3   84  44.0  54.0
# 4   84  43.0  56.0

# %%
y = df['TS1'].dropna()

media = y.mean()
print(f"Média: {media}")

desvio_padrao = y.std()
print(f"Desvio Padrão: {desvio_padrao}")
# Out:
# Média: 85.25
# Desvio Padrão: 1.9194643613111013

# %%
# Passo: Criar o gráfico de distribuição normal
plt.figure(figsize=(8, 6))
plt.hist(y, bins=5, density=True, alpha=0.6, color='b')

# Calcular a média e o desvio padrão da coluna
media = np.mean(y)
desvio_padrao = np.std(y)

# Gerar o gráfico da curva normal teórica
x = np.linspace(min(y), max(y), 100)
y = (1 / (np.sqrt(2 * np.pi) * desvio_padrao)) * np.exp(-0.5 * ((x - media) / desvio_padrao) ** 2)
plt.plot(x, y, 'r', linewidth=2)

# Configurar o título e os rótulos dos eixos
plt.title('Distribuição Normal da Coluna')
plt.xlabel('Valor')
plt.ylabel('Densidade')

# Mostrar o gráfico
plt.show()

# %%
# Create a simple line plot
plt.figure(figsize=(10,6))
plt.plot(df.index, df['TS1'], label='Value')

# Adding labels and title
plt.xlabel('TS1')
plt.ylabel('Value')
plt.title('Time Series Plot')
plt.legend()

# Show the plot
plt.show()

# %%
# Create a simple line plot
plt.figure(figsize=(10,6))
plt.plot(df.index, df['TS2'], label='Value')

# Adding labels and title
plt.xlabel('TS2')
plt.ylabel('Value')
plt.title('Time Series Plot')
plt.legend()

# Show the plot
plt.show()

# %%
# Create a simple line plot
plt.figure(figsize=(10,6))
plt.plot(df.index, df['TS3'], label='Value')

# Adding labels and title
plt.xlabel('TS3')
plt.ylabel('Value')
plt.title('Time Series Plot')
plt.legend()

# Show the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# Convert to a DataFrame
df_ts1 = df['TS1'].dropna()

# Plot autocorrelation function with specified number of lags
plot_acf(df_ts1, lags=30)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# Convert to a DataFrame
df_ts2 = df['TS2'].dropna()

# Plot autocorrelation function with specified number of lags
plot_acf(df_ts2, lags=30)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf

# Convert to a DataFrame
df_ts3 = df['TS3'].dropna()

# Plot autocorrelation function with specified number of lags
plot_acf(df_ts3, lags=30)
plt.show()
